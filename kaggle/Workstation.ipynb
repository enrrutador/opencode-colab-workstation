# %% [markdown]
# # OpenCode Cloud Workstation — Kaggle
# Workstation persistente y reanudable para OpenCode sobre Kaggle.
# 1. Configura OPENCODE_CLOUD_DATASET, NVIDIA_API_KEY, GITHUB_REPO, GITHUB_TOKEN en Kaggle Secrets.
# 2. Ejecuta esta celda.

# %%
import opencode_kaggle.bootstrap as bs
info = bs.bootstrap()
print(info)
